# %% [markdown]
# # Math PS5

# %%
import numpy as np
from matplotlib import pyplot as plt

# %% [markdown]
# ## Exercise 1

# %%
#initialize grids
xgrid = np.linspace(0, 6, 100)
ygrid = np.linspace(0, 6, 100)
X, Y = np.meshgrid(xgrid, ygrid)

#Get constraints in form y(x), x
const1 = lambda x: (-4 - 2*x) / -3
const2 = lambda x: (1 - x)/-6
const3 = lambda x: 6 - x

#Define func
f = lambda x, y: 5*x-4*y

const1grid= np.array(const1(xgrid))
const2grid= np.array(const2(xgrid))
const3grid= np.array(const3(xgrid))

plt.plot(xgrid, const1grid, label = "2x - 3y = -4")
plt.plot(xgrid, const2grid, label = "x - 6y = 1")
plt.plot(xgrid, const3grid, label = "x + y = 6")
plt.plot(xgrid, np.zeros(100), label = "x = 0")
plt.plot(np.zeros(100), ygrid, label = "y = 0")
plt.legend(loc='center left', bbox_to_anchor=(1.2, 0.5))
plt.contourf(X, Y, f(X, Y), cmap ="viridis")
plt.plot(14/5, 16/5, 'o', color = "red")
plt.text(1, 3.5, "P", fontsize =20, color = "red")
plt.xlabel('x')
plt.ylabel('y')
plt.title('Constrained Optimum of 5x-4y')
plt.colorbar()

# %% [markdown]
# The region labeled "P" is the feasible set, the function values are colormapped, and the optimal point is $(\frac{14}{5},\frac{16}{5} )$

# %% [markdown]
# ## Problem 2

# %% [markdown]
# Everywhere I have $x_2 = y$.

# %%
#initialize grids
xgrid = np.linspace(-1, 8, 100)
ygrid = np.linspace(-1, 6, 100)
X, Y = np.meshgrid(xgrid, ygrid)

#Get constraints in form y(x), x
const1 = lambda x: (15 - x) / 3
const2 = lambda x: (18 - 2*x)/3
const3 = lambda x: -4 + x

#Define func
f = lambda x, y: 3*x+y

const1grid= np.array(const1(xgrid))
const2grid= np.array(const2(xgrid))
const3grid= np.array(const3(xgrid))

plt.plot(xgrid, const1grid, label = "x + 3y = 15")
plt.plot(xgrid, const2grid, label = "2x + 3y = 18")
plt.plot(xgrid, const3grid, label = "x - y = 4")
plt.plot(xgrid, np.zeros(100), label = "x = 0")
plt.plot(np.zeros(100), ygrid, label = "y = 0")
plt.legend(loc='center left', bbox_to_anchor=(1.2, 0.5))
plt.contourf(X, Y, f(X, Y), cmap ="viridis")
plt.plot(6, 2, 'o', color = "red")
plt.text(2, 1, "P", fontsize =20, color = "red")
plt.xlabel('x')
plt.ylabel('y')
plt.xlim(-1, 8)
plt.ylim(-1, 6)
plt.title('Constrained Optimum of 3x + y')
plt.colorbar()

# %% [markdown]
# P is the feasible set. The vertices are $(0, 0), (0, 4), (6, 2), (3, 4),$ and $(0, 5)$. The optimum of $20$ is attained at the red point $(6, 2)$.

# %%
#initialize grids
xgrid = np.linspace(-1, 30, 100)
ygrid = np.linspace(-1, 30, 100)
X, Y = np.meshgrid(xgrid, ygrid)

#Get constraints in form y(x), x
const1 = lambda x: 11 + x
const2 = lambda x: 27 - x
const3 = lambda x: (90 - 2*x) / 5

#Define func
f = lambda x, y: 4*x+6*y

const1grid= np.array(const1(xgrid))
const2grid= np.array(const2(xgrid))
const3grid= np.array(const3(xgrid))

plt.plot(xgrid, const1grid, label = "-x + y = 11")
plt.plot(xgrid, const2grid, label = "x + y = 27")
plt.plot(xgrid, const3grid, label = "2x + 5y = 90")
plt.plot(xgrid, np.zeros(100), label = "x = 0")
plt.plot(np.zeros(100), ygrid, label = "y = 0")
plt.legend(loc='center left', bbox_to_anchor=(1.2, 0.5))
plt.contourf(X, Y, f(X, Y), cmap ="viridis")
plt.plot(15, 12, 'o', color = "red")
plt.text(11, 5, "P", fontsize =20, color = "red")
plt.xlabel('x')
plt.ylabel('y')
plt.xlim(-1, 30)
plt.ylim(-1, 30)
plt.title('Constrained Optimum of 4x + 6y')
plt.colorbar()

# %% [markdown]
# The vertices are $(0,0), (0, 11), (5, 16), (15, 12), (27, 0)$. The optimum of $132$ is attained at $(15, 12)$.
